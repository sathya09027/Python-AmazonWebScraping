# %%
    #Import Libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
    #Connect to Website


URL="https://www.amazon.nl/-/en/Candymix-Metal-Detector-Evolution-T-Shirt/dp/B01M1VKPYU/ref=sr_1_5?crid=33P3KT0LBSDB4&dib=eyJ2IjoiMSJ9.U7LM9atjzvSC2-jYgwIZEcjzIzutCsqzR_Vj4Zg-TjHzIVZ8rl4eerQ1_ZMUrC5BdQFvbaR7WnjcVTxxWtQ-XYsNRhp7dk3dDW0vrk_dRJQsBbLyWWkyHo8QPD7HdsBkqWQVvYcGIWkzYjGQfjzViQax1L5csuwNZSL68tTTjpGbAC6mbGycL7bPMJn9Yy36GQAUwkzH4cOk5dm-KIxPbEpmR6Z8YB60kucCh0itKoHr_1CQiwQCPFPb7f785RQzqFUdzwZuQXMP6XKxswBigRdmHHTBuj2EowaQ2rIT9C8.nHvS-7ytFFl57fyGzdmm2nhFk_JM5hRUhDyn6Yr6W5I&dib_tag=se&keywords=data%2B%2B%2Banayst%2B%2B%2Btshirt%2Bgot%2Bdata%2Btshirt&qid=1768900686&sprefix=%2Caps%2C143&sr=8-5&th=1&psc=1"
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/143.0.0.0 Safari/537.36"
}
page=requests.get(URL,headers=headers)
soup1=BeautifulSoup(page.content,"html.parser")
soup2=BeautifulSoup(soup1.prettify(),"html.parser")
title=soup2.find(id="productTitle").get_text()
brand=soup2.find(id="bylineInfo").get_text()
print(title)
print(brand)
# Out:
#                  Candymix - Metal Detector Evolution of Man - Men's T-Shirt Top T-Shirt
#
#
#                 Brand: Candymix

# %%
brand=brand.strip()[7:]
title=title.strip()[11:]
print(title)
print(brand)
# Out:
# Metal Detector Evolution of Man - Men's T-Shirt Top T-Shirt
# Candymix

# %%
import datetime
today=datetime.date.today()
print(today)
# Out:
# 2026-01-20

# %%
      #Create csv file

import csv
header=["title","brand","Date"]
data=[title,brand,today]
with open("AmazonWebScraperDataset.csv","w",newline="",encoding="UTF8")as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sathy

# %%
import datetime
today=datetime.date.today()
print(today)
# Out:
# 2026-01-20

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sathy\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                title     brand        Date
# 0  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20

# %%
      #Appending the data to Csv

with open("AmazonWebScraperDataset.csv","a+",newline="",encoding="UTF8")as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sathy\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                title     brand        Date
# 0  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 1  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 2  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20

# %%
def check_brand():
    URL="https://www.amazon.nl/-/en/Candymix-Metal-Detector-Evolution-T-Shirt/dp/B01M1VKPYU/ref=sr_1_5?crid=33P3KT0LBSDB4&dib=eyJ2IjoiMSJ9.U7LM9atjzvSC2-jYgwIZEcjzIzutCsqzR_Vj4Zg-TjHzIVZ8rl4eerQ1_ZMUrC5BdQFvbaR7WnjcVTxxWtQ-XYsNRhp7dk3dDW0vrk_dRJQsBbLyWWkyHo8QPD7HdsBkqWQVvYcGIWkzYjGQfjzViQax1L5csuwNZSL68tTTjpGbAC6mbGycL7bPMJn9Yy36GQAUwkzH4cOk5dm-KIxPbEpmR6Z8YB60kucCh0itKoHr_1CQiwQCPFPb7f785RQzqFUdzwZuQXMP6XKxswBigRdmHHTBuj2EowaQ2rIT9C8.nHvS-7ytFFl57fyGzdmm2nhFk_JM5hRUhDyn6Yr6W5I&dib_tag=se&keywords=data%2B%2B%2Banayst%2B%2B%2Btshirt%2Bgot%2Bdata%2Btshirt&qid=1768900686&sprefix=%2Caps%2C143&sr=8-5&th=1&psc=1"
    headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/143.0.0.0 Safari/537.36"
    }
    page=requests.get(URL,headers=headers)
    soup1=BeautifulSoup(page.content,"html.parser")
    soup2=BeautifulSoup(soup1.prettify(),"html.parser")
    title=soup2.find(id="productTitle").get_text()
    brand=soup2.find(id="bylineInfo").get_text()
  
    brand=brand.strip()[7:]
    title=title.strip()[11:]
    
    import datetime
    today=datetime.date.today()
    
    import csv
    header=["title","brand","Date"]
    data=[title,brand,today]
    with open("AmazonWebScraperDataset.csv","a+",newline="",encoding="UTF8")as f:
      writer=csv.writer(f)
      writer.writerow(data)

# %%
while(True):
    check_brand()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 3
#       1 while(True):
#       2     check_brand()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sathy\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                title     brand        Date
# 0  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 1  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 2  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 3  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20
# 4  Metal Detector Evolution of Man - Men's T-Shir...  Candymix  2026-01-20

# %%
title_tag = soup2.find(id="productTitle")
brand_tag = soup2.find(id="bylineInfo")

if title_tag and brand_tag:
    title = title_tag.get_text(strip=True)
    brand = brand_tag.get_text(strip=True)
    print(title, brand)
else:
    print("Title or Brand not found – page blocked or changed")
# Out:
# Title or Brand not found – page blocked or changed

# %%
print(page.status_code)
# Out:
# 200
